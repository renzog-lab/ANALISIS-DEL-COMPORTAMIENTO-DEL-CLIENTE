# %%
import pandas as pd

# %%
df = pd.read_csv('customer_shopping_behavior.csv')

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   str
#  3   Item Purchased          3900 non-null   str
#  4   Category                3900 non-null   str
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   str
#  7   Size                    3900 non-null   str
#  8   Color                   3900 non-null   str
#  9   Season                  3900 non-null   str
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   str
#  12  Shipping Type           3900 non-null   str
#  13  Discount Applied        3900 non-null   str
#  14  Promo Code Used         3900 non-null   str
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
#identificar los nulos
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
mediana=df['Review Rating'].median()
print(mediana)
# Out:
# 3.8

# %%
#imputar valores nulos 
df['Review Rating']=df.groupby('Category')['Review Rating'].transform(lambda x:x.fillna(x.median()))

# %%
#identificar los nulo
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
#cambiamos a minuscula y llenamos los espacios en blanco con guion abajo a los titulos o campos
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
import pandas as pd
bins = [0,17,35,60,100]
labels = ['menor de edad','joven','adulto','senior']

#etiquetado
df['grupo_edad']=pd.cut(df['age'],bins=bins,labels=labels)

# %%
#mostrar las columnas
df[['age','grupo_edad']].head(10)
# Out:
#    age grupo_edad
# 0   55     adulto
# 1   19      joven
# 2   50     adulto
# 3   21      joven
# 4   45     adulto
# 5   46     adulto
# 6   63     senior
# 7   27      joven
# 8   26      joven
# 9   57     adulto

# %%
df
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 0               1   55    Male         Blouse     Clothing               53
# 1               2   19    Male        Sweater     Clothing               64
# 2               3   50    Male          Jeans     Clothing               73
# 3               4   21    Male        Sandals     Footwear               90
# 4               5   45    Male         Blouse     Clothing               49
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing               28
# 3896         3897   52  Female       Backpack  Accessories               49
# 3897         3898   46  Female           Belt  Accessories               33
# 3898         3899   44  Female          Shoes     Footwear               77
# 3899         3900   52  Female        Handbag  Accessories               81
#
# ...

# %%
#creamos nueva columa para clasificar las frecuencias
frecuency_mapping ={
       'Fortnightly':14,
       'Weekly':7,
       'Annually':365,
       'Quarterly':90,
       'Bi-Weekly':14,
       'Monthly':30,
       'Every 3 Months':90
}

#crear columna metodo map 
df['frequency_of_purchases:days']=df['frequency_of_purchases'].map(frecuency_mapping)

# %%
df[['frequency_of_purchases:days','frequency_of_purchases']].head(10)
# Out:
#    frequency_of_purchases:days frequency_of_purchases
# 0                           14            Fortnightly
# 1                           14            Fortnightly
# 2                            7                 Weekly
# 3                            7                 Weekly
# 4                          365               Annually
# 5                            7                 Weekly
# 6                           90              Quarterly
# 7                            7                 Weekly
# 8                          365               Annually
# 9                           90              Quarterly

# %%
#revisamos 2 columnas
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
#eliminamos una de ellas
df=df.drop('promo_code_used',axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'grupo_edad', 'frequency_of_purchases:days'],
#       dtype='str')

# %%
df
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 0               1   55    Male         Blouse     Clothing               53
# 1               2   19    Male        Sweater     Clothing               64
# 2               3   50    Male          Jeans     Clothing               73
# 3               4   21    Male        Sandals     Footwear               90
# 4               5   45    Male         Blouse     Clothing               49
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing               28
# 3896         3897   52  Female       Backpack  Accessories               49
# 3897         3898   46  Female           Belt  Accessories               33
# 3898         3899   44  Female          Shoes     Footwear               77
# 3899         3900   52  Female        Handbag  Accessories               81
#
# ...

# %%
#cambiar de nombre a las columnas

diccionario = {
      "customer_id":"idcliente",
      "age":"edad",
      "gender":"sexo",
      "item_purchased":"articulo_comprado",
      "category":"categoria",
      "purchase_amount":"monto_de_comprar",
      "location":"ubicacion",
      "size":"tamaño",
      "color":"color",
      "season":"temporada",
      "review_rating":"calificacion_del_cliente",
      "subscription_status":"estado_de_suscripcion",
      "shipping_type":"tipo_de_envio",
      "discount_applied":"descuento_aplicado",
      "previous_purchases":"compras_anteriores",
      "payment_method":"metodo_de_pago",
      "frequency_of_purchases":"frecuencia_de_compra",
      "grupo_edad":"grupo_edad",
      "frequency_of_purchases:days":"frecuencia_de_compras_dias"

}  

df=df.rename(columns=diccionario)

# %%
df
# Out:
#       idcliente  edad    sexo articulo_comprado    categoria  \
# 0             1    55    Male            Blouse     Clothing
# 1             2    19    Male           Sweater     Clothing
# 2             3    50    Male             Jeans     Clothing
# 3             4    21    Male           Sandals     Footwear
# 4             5    45    Male            Blouse     Clothing
# ...         ...   ...     ...               ...          ...
# 3895       3896    40  Female            Hoodie     Clothing
# 3896       3897    52  Female          Backpack  Accessories
# 3897       3898    46  Female              Belt  Accessories
# 3898       3899    44  Female             Shoes     Footwear
# 3899       3900    52  Female           Handbag  Accessories
#
#       monto_de_comprar      ubicacion tamaño      color temporada  \
# 0                   53       Kentucky      L       Gray    Winter
# 1                   64          Maine      L     Maroon    Winter
# ...

# %% [markdown]
# CONEXION CON SQL : IMPORTACION DEL DATAFRAME A LA BASE DE DATOS COMPORTAMIENTO DEL CLIENTE

# %%
#instalamos librerias
# !pip install pyodbc sqlalchemy
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#instalamos los modulos
import pyodbc
import sqlalchemy
print("pyodbc ", pyodbc.version)
print("sqlalchemy: ",sqlalchemy.__version__)
# Out:
# pyodbc  5.3.0
# sqlalchemy:  2.0.51

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'ODBC Driver 17 for SQL Server', 'ODBC Driver 18 for SQL Server']

# %%
#conexion con sql server
from sqlalchemy import create_engine
from urllib.parse import quote_plus

driver=quote_plus('ODBC Driver 17 for SQL Server')

engine= create_engine(
       f"mssql+pyodbc://@localhost/ComportamientoDelCliente?driver={driver}&trusted_connection=yes"
       )

print("conexion creada correctamente")
# Out:
# conexion creada correctamente

# %%
#conexion con sql server
from sqlalchemy import create_engine
from urllib.parse import quote_plus

host=r"DESKTOP-V234VOB"
database="ComportamientoDelCliente"

driver=quote_plus('ODBC Driver 17 for SQL Server')

engine= create_engine(
       f"mssql+pyodbc://@{host}/{database}?driver={driver}&trusted_connection=yes"
)

#llevamos la tabla ala BD ---df

df.to_sql("cliente",engine,if_exists="replace",index=False)
# Out:
# 50

# %%
import pandas as pd

# %%
consulta = """
 select idcliente,edad
 from cliente
 where edad>40
"""

resultado = pd.read_sql(consulta,engine)
print (resultado)
# Out:
#       idcliente  edad
# 0             1    55
# 1             3    50
# 2             5    45
# 3             6    46
# 4             7    63
# ...         ...   ...
# 2221       3895    66
# 2222       3897    52
# 2223       3898    46
# 2224       3899    44
# 2225       3900    52
#
# [2226 rows x 2 columns]
